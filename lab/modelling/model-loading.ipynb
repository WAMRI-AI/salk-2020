# %%
import fastai
from fastai import *
from fastai.vision import *
from fastai.callbacks import *
from fastai.script import *
import fastai.vision.learner as fvl
from fastai.vision.learner import cnn_config
from fastai.vision.models.unet import DynamicUnet

from skimage import filters
from skimage.util import random_noise
from functools import partial
from metrics import sr_metrics

# %%
torch.cuda.set_device(3)

# %% [markdown]
# # Data Loading

# %%
# Modify accordingly
path = Path('/home/alaa/Dropbox (BPHO)/BPHO Staff/USF/EM/')

dataset_name = 'semi-synthetic_tSEM'

lr_name = f'training/trainsets/crappified/'
lr_path = path/f'{lr_name}'
lr_files = list(lr_path.glob('*.tif'))

hr_name = f'training/trainsets/hr/'
hr_path = path/f'{hr_name}'
hr_files = list(hr_path.glob('*.tif'))

print('Processing '+str(len(lr_files))+' files...')
# Out:
# Processing 99997 files...

# %%
def get_data(x_train, y_train):
    def map_to_hr(x):
        return Path(str(y_train/x.relative_to(x_train).with_suffix(".tif")).replace('lr', 'hr'))
    src = (ImageImageList
          .from_folder(x_train, convert_mode="L")
          .split_none()
          .label_from_func(map_to_hr, convert_mode="L"))
    return src

# %%
d = get_data(lr_path, hr_path)

# %%
d.train
# Out:
# LabelList (99997 items)
# x: ImageImageList
# Image (1, 150, 225),Image (1, 150, 225),Image (1, 150, 225),Image (1, 150, 225),Image (1, 150, 225)
# y: ImageList
# Image (1, 600, 900),Image (1, 600, 900),Image (1, 600, 900),Image (1, 600, 900),Image (1, 600, 900)
# Path: /home/alaa/Dropbox (BPHO)/BPHO Staff/USF/EM/training/trainsets/crappified

# %%
def _my_noise(x, gauss_sigma:uniform=0.01, pscale:uniform=10):
    xn = x.numpy()
    xorig_max = xn.max()

    xn = random_noise(xn, mode='salt', amount=0.005)
    xn = random_noise(xn, mode='pepper', amount=0.005)
    lvar = filters.gaussian(x, sigma=5) + 1e-10
    xn = random_noise(xn, mode='localvar', local_vars=lvar*0.5)
    #xn = np.random.poisson(xn*pscale)/pscale
    #xn += np.random.normal(0, gauss_sigma*xn.std(), size=x.shape)
    x = x.new(xn)
    new_max = xn.max()
    if new_max > 0:
        xn /= new_max
    xn *= xorig_max
    return x


my_noise = TfmPixel(_my_noise)

# %%
def get_xy_transforms(max_rotate=10., min_zoom=1., max_zoom=4., use_cutout=False, use_noise=False, xtra_tfms=None,
                      gauss_sigma=(0.4,0.7), pscale=(5,30)):
    base_tfms = [[
            rand_crop(),
            dihedral_affine(),
            rotate(degrees=(-max_rotate,max_rotate)),
            rand_zoom(min_zoom, max_zoom)],
        [crop_pad()]]

    y_tfms = [[tfm for tfm in base_tfms[0]], [tfm for tfm in base_tfms[1]]]
    x_tfms = [[tfm for tfm in base_tfms[0]], [tfm for tfm in base_tfms[1]]]
    if use_cutout: x_tfms[0].append(cutout(n_holes=(5,10)))
    if use_noise:
        x_tfms[0].append(my_noise(gauss_sigma=gauss_sigma, pscale=pscale))
        #x_tfms[1].append(my_noise(gauss_sigma=(0.01,0.05),pscale=(5,30)))

    if xtra_tfms:
        for tfm in xtra_tfms:
            x_tfms[0].append(tfm)

    return x_tfms, y_tfms

# %%
def process_data(data, bs=8, size=256, scale=4, num_workers=4):
    x_tfms, y_tfms = get_xy_transforms()
    x_sz = size // scale
    
    data = (data.transform(x_tfms, size=x_sz)
               .transform_y(y_tfms, size=size)
               .databunch(bs=bs, num_workers=num_workers)
               .normalize(do_y=True))
    data.c = 3
    return data

# %%
db = process_data(d)

# %%
db.show_batch(rows=3, cmap=plt.cm.gray)

# %% [markdown]
# # Modelling

# %%
def wnres_unet_learner(data, arch, in_c=1, out_c=1, wnres_args=None, bilinear_upsample=True, **kwargs):
    if wnres_args is None: wnres_args = {}
    model, meta = wnres_unet_model(in_c, out_c, arch, **wnres_args)
    learn = Learner(data, model, **kwargs)
    learn.split(meta['split'])
    apply_init(model[2], nn.init.kaiming_normal_)
    if bilinear_upsample:
        learn.model = BilinearWrapper(learn.model)
    return learn

# %%
def wnres_unet_model(in_c, out_c, arch, blur=True, blur_final=True, self_attention=True, last_cross=True, bottle=True, norm_type=NormType.Weight, **wnres_args):
    meta = cnn_config(arch)
    enc_model = arch(c_in=in_c)
    cut = cnn_config(arch)['cut']
    body = nn.Sequential(*list(enc_model.children())[:cut])

    model = DynamicUnet(body,
                        n_classes=out_c,
                        blur=blur,
                        blur_final=blur_final,
                        self_attention=self_attention,
                        norm_type=norm_type,
                        last_cross=last_cross,
                        bottle=bottle, **wnres_args)
    return model, meta

# %%
class BilinearWrapper(nn.Module):
    def __init__(self, model, scale=4, mode='bilinear'):
        super().__init__()
        self.model = model
        self.scale = scale
        self.mode = mode

    def forward(self, x):
        return self.model(F.interpolate(x, scale_factor=self.scale, mode=self.mode, align_corners=False))

# %%
def wnresnet(expansion, n_layers, name, pretrained=False, **kwargs):
    model = WNResNet(expansion, n_layers, **kwargs)
    if pretrained: model.load_state_dict(model_zoo.load_url(model_urls[name]))
    return model

# %%
def _wnresnet_split(m:nn.Module): return (m[0][6],m[1])
_wnresnet_meta     = {'cut':-2, 'split':_wnresnet_split }

# %%
class WNResNet(nn.Sequential):
    def __init__(self, expansion, layers, c_in=3, c_out=1000):
        stem = []
        sizes = [c_in,32,32,64]
        for i in range(3):
            stem.append(conv_layer(sizes[i], sizes[i+1], stride=2 if i==0 else 1))
            #nf = filt_sz(c_in*9)
            #stem.append(conv_layer(c_in, nf, stride=2 if i==1 else 1))
            #c_in = nf

        block_szs = [64//expansion,64,128,256,512]
        blocks = [self._make_layer(expansion, block_szs[i], block_szs[i+1], l, 1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        super().__init__(
            *stem,
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            *blocks,
            nn.AdaptiveAvgPool2d(1), Flatten(),
            nn.Linear(block_szs[-1]*expansion, c_out),
        )
        init_cnn(self)

    def _make_layer(self, expansion, ni, nf, blocks, stride):
        return nn.Sequential(
            *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
              for i in range(blocks)])

# %%
class ResBlock(nn.Module):
    def __init__(self, expansion, ni, nh, stride=1):
        super().__init__()
        nf,ni = nh*expansion,ni*expansion
        layers  = [conv_layer(ni, nh, 1)]
        layers += [
            conv_layer(nh, nf, 3, stride=stride,act=False)
        ] if expansion==1 else [
            conv_layer(nh, nh, 3, stride=stride),
            conv_layer(nh, nf, 1, act=False)
        ]
        self.convs = nn.Sequential(*layers)
        # TODO: check whether act=True works better
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act=False)
        self.pool = noop if stride==1 else nn.AvgPool2d(2, ceil_mode=True)

    def forward(self, x): return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# %%
def conv_layer(ni, nf, ks=3, stride=1, act=True):
    layers = [nn.utils.weight_norm(conv(ni, nf, ks, stride=stride))]
    if act: layers.append(act_fn)
    return nn.Sequential(*layers)

# %%
act_fn = nn.ReLU(inplace=True)

class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

def init_cnn(m):
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    for l in m.children(): init_cnn(l)

def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

def noop(x): return x

# %%
arch = partial(wnresnet, expansion=1, n_layers=[3,4,6,3], name='encoder')

# %%
arch
# Out:
# functools.partial(<function wnresnet at 0x7f43ca2b8840>, expansion=1, n_layers=[3, 4, 6, 3], name='encoder')

# %%
fvl.model_meta[arch] = {**_wnresnet_meta}

# %%
meta = cnn_config(arch)

# %%
encoder = arch(c_in=1)

# %%
encoder
# Out:
# WNResNet(
#   (0): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#   )
#   (1): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#   )
#   (2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#   )
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#   )
#   (5): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (3): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#   )
#   (6): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (3): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (4): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (5): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#   )
#   (7): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=1)
#   (9): Flatten()
#   (10): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# #### Remove last 2 layers

# %%
cut = cnn_config(arch)['cut']

# %%
body = nn.Sequential(*list(encoder.children())[:cut])

# %%
body
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#   )
#   (1): Sequential(
#     (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#   )
#   (2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#   )
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#   )
#   (5): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (3): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#   )
#   (6): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (3): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (4): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (5): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#   )
#   (7): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=1)
# )

# %%
wnres_args = {
            'blur': True,
            'blur_final': True,
            'bottle': True,
            'self_attention': True,
            'last_cross': True
        }
wd = 1e-3

# %%
loss = F.mse_loss

# %%
metrics = sr_metrics

# %%
model_dir = 'model/test/'

# %%
learn = wnres_unet_learner(db, arch, in_c=1, 
                            wnres_args=wnres_args,
                            path=Path('.'), loss_func=loss, 
                            metrics=metrics,
                            model_dir=model_dir, 
                            callback_fns=None, wd=wd)

# %%
model = learn.load('tmp')

# %%
model.show_results(ds_type=DatasetType.Train)

# %%
# learn
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (99997 items)
# x: ImageImageList
# Image (1, 64, 64),Image (1, 64, 64),Image (1, 64, 64),Image (1, 64, 64),Image (1, 64, 64)
# y: ImageList
# Image (1, 256, 256),Image (1, 256, 256),Image (1, 256, 256),Image (1, 256, 256),Image (1, 256, 256)
# Path: /home/alaa/Dropbox (BPHO)/BPHO Staff/USF/EM/training/trainsets/crappified;
#
# Valid: LabelList (0 items)
# x: ImageImageList
#
# y: ImageList
#
# Path: /home/alaa/Dropbox (BPHO)/BPHO Staff/USF/EM/training/trainsets/crappified;
#
# Test: None, model=BilinearWrapper(
#   (model): DynamicUnet(
#     (layers): ModuleList(
#       (0): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (2): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): ReLU(inplace=True)
#         )
#         (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (4): Sequential(
#           (0): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (1): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (2): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (5): Sequential(
#           (0): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               )
#             )
#             (idconv): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#           )
#           (1): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (2): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (3): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (6): Sequential(
#           (0): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               )
#             )
#             (idconv): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#           )
#           (1): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (2): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (3): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (4): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (5): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (7): Sequential(
#           (0): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               )
#             )
#             (idconv): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#           )
#           (1): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#           (2): ResBlock(
#             (convs): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): ReLU(inplace=True)
#               )
#               (1): Sequential(
#                 (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#             )
#           )
#         )
#         (8): AdaptiveAvgPool2d(output_size=1)
#       )
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Sequential(
#         (0): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Sequential(
#           (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (4): UnetBlock(
#         (shuf): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace=True)
#         )
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (relu): ReLU()
#       )
#       (5): UnetBlock(
#         (shuf): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace=True)
#         )
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Sequential(
#           (0): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (relu): ReLU()
#       )
#       (6): UnetBlock(
#         (shuf): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(640, 1280, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace=True)
#         )
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Sequential(
#           (0): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#           (2): SelfAttention(
#             (query): Conv1d(448, 56, kernel_size=(1,), stride=(1,), bias=False)
#             (key): Conv1d(448, 56, kernel_size=(1,), stride=(1,), bias=False)
#             (value): Conv1d(448, 448, kernel_size=(1,), stride=(1,), bias=False)
#           )
#         )
#         (relu): ReLU()
#       )
#       (7): UnetBlock(
#         (shuf): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(448, 896, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace=True)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Sequential(
#           (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (relu): ReLU()
#       )
#       (8): UnetBlock(
#         (shuf): PixelShuffle_ICNR(
#           (conv): Sequential(
#             (0): Conv2d(288, 576, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (shuf): PixelShuffle(upscale_factor=2)
#           (pad): ReplicationPad2d((1, 0, 1, 0))
#           (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#           (relu): ReLU(inplace=True)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Sequential(
#           (0): Conv2d(208, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Sequential(
#           (0): Conv2d(104, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (relu): ReLU()
#       )
#       (9): PixelShuffle_ICNR(
#         (conv): Sequential(
#           (0): Conv2d(104, 416, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (shuf): PixelShuffle(upscale_factor=2)
#         (pad): ReplicationPad2d((1, 0, 1, 0))
#         (blur): AvgPool2d(kernel_size=2, stride=1, padding=0)
#         (relu): ReLU(inplace=True)
#       )
#       (10): MergeLayer()
#       (11): SequentialEx(
#         (layers): ModuleList(
#           (0): Sequential(
#             (0): Conv2d(105, 52, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Sequential(
#             (0): Conv2d(52, 105, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (2): MergeLayer()
#         )
#       )
#       (12): Sequential(
#         (0): Conv2d(105, 1, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<function mse_loss at 0x7f463fdf70d0>, metrics=[<function ssim at 0x7f4631c32e18>, <function psnr at 0x7f4631c35048>, <function norm_ssim at 0x7f4631c35378>, <function norm_psnr at 0x7f4631c35400>], true_wd=True, bn_wd=True, wd=0.001, train_bn=True, path=PosixPath('.'), model_dir='models/tests/', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): ReLU(inplace=True)
#   (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (3): ReLU(inplace=True)
#   (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (5): ReLU(inplace=True)
#   (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (7): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (8): ReLU(inplace=True)
#   (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (10): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (11): ReLU(inplace=True)
#   (12): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (14): ReLU(inplace=True)
#   (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (16): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (17): ReLU(inplace=True)
#   (18): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (19): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (20): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (21): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (22): ReLU(inplace=True)
#   (23): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (24): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (25): ReLU(inplace=True)
#   (26): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (27): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (28): ReLU(inplace=True)
#   (29): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ), Sequential(
#   (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (1): ReLU(inplace=True)
#   (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (4): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (5): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (6): ReLU(inplace=True)
#   (7): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (9): ReLU(inplace=True)
#   (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (11): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (12): ReLU(inplace=True)
#   (13): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (14): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (15): ReLU(inplace=True)
#   (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (17): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (18): ReLU(inplace=True)
#   (19): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (20): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (21): ReLU(inplace=True)
#   (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (23): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (24): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (25): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (26): ReLU(inplace=True)
#   (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (28): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (29): ReLU(inplace=True)
#   (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (31): AdaptiveAvgPool2d(output_size=1)
# ), Sequential(
#   (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (1): ReLU()
#   (2): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (5): ReLU(inplace=True)
#   (6): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1))
#   (7): PixelShuffle(upscale_factor=2)
#   (8): ReplicationPad2d((1, 0, 1, 0))
#   (9): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (10): ReLU(inplace=True)
#   (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): ReLU()
#   (17): Conv2d(768, 1536, kernel_size=(1, 1), stride=(1, 1))
#   (18): PixelShuffle(upscale_factor=2)
#   (19): ReplicationPad2d((1, 0, 1, 0))
#   (20): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (21): ReLU(inplace=True)
#   (22): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (23): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (24): ReLU(inplace=True)
#   (25): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (26): ReLU(inplace=True)
#   (27): ReLU()
#   (28): Conv2d(640, 1280, kernel_size=(1, 1), stride=(1, 1))
#   (29): PixelShuffle(upscale_factor=2)
#   (30): ReplicationPad2d((1, 0, 1, 0))
#   (31): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (32): ReLU(inplace=True)
#   (33): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (34): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (35): ReLU(inplace=True)
#   (36): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (37): ReLU(inplace=True)
#   (38): Conv1d(448, 56, kernel_size=(1,), stride=(1,), bias=False)
#   (39): Conv1d(448, 56, kernel_size=(1,), stride=(1,), bias=False)
#   (40): Conv1d(448, 448, kernel_size=(1,), stride=(1,), bias=False)
#   (41): ParameterModule()
#   (42): ReLU()
#   (43): Conv2d(448, 896, kernel_size=(1, 1), stride=(1, 1))
#   (44): PixelShuffle(upscale_factor=2)
#   (45): ReplicationPad2d((1, 0, 1, 0))
#   (46): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (47): ReLU(inplace=True)
#   (48): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (49): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (50): ReLU(inplace=True)
#   (51): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (52): ReLU(inplace=True)
#   (53): ReLU()
#   (54): Conv2d(288, 576, kernel_size=(1, 1), stride=(1, 1))
#   (55): PixelShuffle(upscale_factor=2)
#   (56): ReplicationPad2d((1, 0, 1, 0))
#   (57): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (58): ReLU(inplace=True)
#   (59): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (60): Conv2d(208, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (61): ReLU(inplace=True)
#   (62): Conv2d(104, 104, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (63): ReLU(inplace=True)
#   (64): ReLU()
#   (65): Conv2d(104, 416, kernel_size=(1, 1), stride=(1, 1))
#   (66): PixelShuffle(upscale_factor=2)
#   (67): ReplicationPad2d((1, 0, 1, 0))
#   (68): AvgPool2d(kernel_size=2, stride=1, padding=0)
#   (69): ReLU(inplace=True)
#   (70): MergeLayer()
#   (71): Conv2d(105, 52, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (72): ReLU(inplace=True)
#   (73): Conv2d(52, 105, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (74): ReLU(inplace=True)
#   (75): MergeLayer()
#   (76): Conv2d(105, 1, kernel_size=(1, 1), stride=(1, 1))
# )], add_time=True, silent=False)

# %%
# lr = slice(None, 1e-4, None)

# %%
learn.fit_one_cycle(5, lr)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 37:07<2:28:29]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>ssim</th>
#       <th>psnr</th>
#       <th>norm_ssim</th>
#       <th>norm_psnr</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.110766</td>
#       <td>#na#</td>
#       <td>37:07</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7851' class='' max='12499', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       62.81% [7851/12499 24:46<14:40 0.1103]
#     </div>
